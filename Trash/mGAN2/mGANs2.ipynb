# %% [markdown]
# mutual information

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
hyperparams = {
    'num_generators': 10,      # Number of generators
    'latent_dim': 100,        # Dimension of the latent space (input noise)
    'num_epochs': 50,         # Number of training epochs
    'batch_size': 64,         # Batch size
    'learning_rate': 0.0002,  # Learning rate for optimizers
    'image_size': 28,         # MNIST image size
    'num_classes': 10,        # Number of classes in MNIST
    'beta1': 0.5,             # Beta1 hyperparameter for Adam optimizer
    'mi_loss_weight': 0.1,    # Weight for mutual information loss
    'save_images': False,      # Whether to save generated images
    'output_dir': 'images',   # Directory to save images
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# %%
def get_data_loader(batch_size, image_size):
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ])
    dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return dataloader

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim, image_size):
        super(Generator, self).__init__()
        self.image_size = image_size
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),
            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(True),
            nn.Linear(1024, image_size * image_size),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(z.size(0), 1, self.image_size, self.image_size)
        return img

class Discriminator(nn.Module):
    def __init__(self, image_size):
        super(Discriminator, self).__init__()
        self.image_size = image_size
        self.model = nn.Sequential(
            nn.Linear(image_size * image_size, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.4),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.4),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity

class Classifier(nn.Module):
    def __init__(self, image_size, num_classes):
        super(Classifier, self).__init__()
        self.image_size = image_size
        self.model = nn.Sequential(
            nn.Linear(image_size * image_size, 512),
            nn.ReLU(True),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(True),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes),
            nn.Softmax(dim=1)
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        class_probs = self.model(img_flat)
        return class_probs

# %%
def initialize_models(hyperparams):
    num_generators = hyperparams['num_generators']
    latent_dim = hyperparams['latent_dim']
    image_size = hyperparams['image_size']
    num_classes = hyperparams['num_classes']
    device = hyperparams['device']
    
    generators = [Generator(latent_dim, image_size).to(device) for _ in range(num_generators)]
    discriminator = Discriminator(image_size).to(device)
    classifier = Classifier(image_size, num_classes).to(device)
    
    return generators, discriminator, classifier

# %%
def initialize_optimizers(generators, discriminator, classifier, hyperparams):
    learning_rate = hyperparams['learning_rate']
    beta1 = hyperparams['beta1']
    
    optimizer_G = [optim.Adam(g.parameters(), lr=learning_rate, betas=(beta1, 0.999)) for g in generators]
    optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(beta1, 0.999))
    optimizer_C = optim.Adam(classifier.parameters(), lr=learning_rate, betas=(beta1, 0.999))
    
    return optimizer_G, optimizer_D, optimizer_C

# %%
def mutual_information_loss(gen_imgs1, gen_imgs2, classifier):
    # Compute the outputs
    probs1 = classifier(gen_imgs1)
    probs2 = classifier(gen_imgs2)
    # Compute joint distribution approximation
    joint_probs = probs1.unsqueeze(2) * probs2.unsqueeze(1)
    joint_probs = joint_probs.mean(dim=0)  # Average over batch
    # Compute marginal distributions
    marg_probs1 = probs1.mean(dim=0)
    marg_probs2 = probs2.mean(dim=0)
    # Compute mutual information
    mi_matrix = joint_probs * torch.log(joint_probs / (marg_probs1.unsqueeze(1) * marg_probs2.unsqueeze(0) + 1e-8) + 1e-8)
    mi = mi_matrix.sum()
    return mi

# %%
def generate_images(epoch, generators, hyperparams):
    device = hyperparams['device']
    latent_dim = hyperparams['latent_dim']
    num_generators = hyperparams['num_generators']
    image_size = hyperparams['image_size']
    
    with torch.no_grad():
        # Generate images
        z = torch.randn(num_generators * 10, latent_dim, device=device)
        gen_imgs = []
        for idx, g in enumerate(generators):
            gen_img = g(z[idx*10:(idx+1)*10])
            gen_imgs.append(gen_img)
        gen_imgs = torch.cat(gen_imgs, dim=0)
        gen_imgs = gen_imgs * 0.5 + 0.5  # Rescale images to [0, 1]
        grid = vutils.make_grid(gen_imgs.cpu(), nrow=10)
        plt.figure(figsize=(10,10))
        plt.imshow(np.transpose(grid, (1,2,0)))
        plt.axis('off')
        plt.title(f'Epoch {epoch}')
        plt.show()
        # Save the figure if needed
        if hyperparams['save_images']:
            os.makedirs(hyperparams['output_dir'], exist_ok=True)
            plt.savefig(f"{hyperparams['output_dir']}/epoch_{epoch}.png")
            plt.close()

# %%
def train(hyperparams):
    # Unpack hyperparameters
    num_epochs = hyperparams['num_epochs']
    batch_size = hyperparams['batch_size']
    latent_dim = hyperparams['latent_dim']
    num_generators = hyperparams['num_generators']
    mi_loss_weight = hyperparams['mi_loss_weight']
    device = hyperparams['device']
    
    # Get data loader
    dataloader = get_data_loader(batch_size, hyperparams['image_size'])
    
    # Initialize models and optimizers
    generators, discriminator, classifier = initialize_models(hyperparams)
    optimizer_G, optimizer_D, optimizer_C = initialize_optimizers(generators, discriminator, classifier, hyperparams)
    
    # Loss functions
    adversarial_loss = nn.BCELoss()
    classification_loss = nn.CrossEntropyLoss()
    
    # Lists to store loss values for plotting
    d_losses = []
    g_losses = []
    c_losses = []
    epochs_list = []
    
    # Training loop
    for epoch in range(num_epochs):
        for i, (imgs, labels) in enumerate(dataloader):
            # Configure inputs
            real_imgs = imgs.to(device)
            labels = labels.to(device)
            batch_size_curr = real_imgs.size(0)
            
            # Adversarial ground truths
            valid = torch.ones(batch_size_curr, 1, device=device)
            fake = torch.zeros(batch_size_curr, 1, device=device)
            
            # ---------------------
            #  Train Discriminator
            # ---------------------
            optimizer_D.zero_grad()
            # Real images
            real_validity = discriminator(real_imgs)
            d_real_loss = adversarial_loss(real_validity, valid)
            # Fake images from all generators
            fake_imgs = []
            for g in generators:
                z = torch.randn(batch_size_curr, latent_dim, device=device)
                gen_imgs = g(z)
                fake_imgs.append(gen_imgs)
            fake_imgs_all = torch.cat(fake_imgs, dim=0)
            fake_validity = discriminator(fake_imgs_all.detach())
            d_fake_loss = adversarial_loss(fake_validity, fake.repeat(num_generators, 1))
            # Total discriminator loss
            d_loss = (d_real_loss + d_fake_loss) / 2
            d_loss.backward()
            optimizer_D.step()
            
            # ---------------------
            #  Train Classifier
            # ---------------------
            optimizer_C.zero_grad()
            # Classifier loss on real images
            class_probs = classifier(real_imgs)
            c_loss = classification_loss(class_probs, labels)
            c_loss.backward()
            optimizer_C.step()
            
            # -----------------
            #  Train Generators
            # -----------------
            total_g_loss = 0  # To accumulate generator losses
            for idx, g in enumerate(generators):
                optimizer_G[idx].zero_grad()
                z = torch.randn(batch_size_curr, latent_dim, device=device)
                gen_imgs = g(z)
                # Adversarial loss
                validity = discriminator(gen_imgs)
                g_loss = adversarial_loss(validity, valid)
                # Mutual Information Loss
                mi_loss = 0
                for jdx, other_g in enumerate(generators):
                    if idx != jdx:
                        z_other = torch.randn(batch_size_curr, latent_dim, device=device)
                        gen_imgs_other = other_g(z_other).detach()
                        mi_loss += mutual_information_loss(gen_imgs, gen_imgs_other, classifier)
                # Total generator loss
                total_loss = g_loss + mi_loss_weight * mi_loss
                total_loss.backward()
                optimizer_G[idx].step()
                total_g_loss += total_loss.item()
            
            # --------------
            # Log Progress
            # --------------
            if i % 100 == 0:
                avg_g_loss = total_g_loss / num_generators
                print(f"[Epoch {epoch+1}/{num_epochs}] [Batch {i}/{len(dataloader)}] "
                      f"[D loss: {d_loss.item():.4f}] [G loss: {avg_g_loss:.4f}] [C loss: {c_loss.item():.4f}]")
        
        # Store loss values for plotting
        d_losses.append(d_loss.item())
        g_losses.append(avg_g_loss)
        c_losses.append(c_loss.item())
        epochs_list.append(epoch+1)
        
        # Generate and save images every 5 epochs
        if (epoch + 1) % 5 == 0:
            generate_images(epoch+1, generators, hyperparams)
    
    # Plot the learning curves after training
    plt.figure(figsize=(10,5))
    plt.plot(epochs_list, d_losses, label='Discriminator Loss')
    plt.plot(epochs_list, g_losses, label='Generator Loss')
    plt.plot(epochs_list, c_losses, label='Classifier Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss Curves')
    plt.show()

# %%
# Start training
train(hyperparams)
# Out:
# [Epoch 1/50] [Batch 0/938] [D loss: 0.6822] [G loss: 0.6496] [C loss: 2.3011]
# [Epoch 1/50] [Batch 100/938] [D loss: 0.6646] [G loss: 0.8525] [C loss: 1.8616]
# [Epoch 1/50] [Batch 200/938] [D loss: 0.6481] [G loss: 0.8440] [C loss: 1.7306]
# [Epoch 1/50] [Batch 300/938] [D loss: 0.6525] [G loss: 0.8204] [C loss: 1.6658]
# [Epoch 1/50] [Batch 400/938] [D loss: 0.6475] [G loss: 0.6982] [C loss: 1.6514]
# [Epoch 1/50] [Batch 500/938] [D loss: 0.6425] [G loss: 0.8916] [C loss: 1.6103]
# [Epoch 1/50] [Batch 600/938] [D loss: 0.6389] [G loss: 0.7221] [C loss: 1.5804]
# [Epoch 1/50] [Batch 700/938] [D loss: 0.6034] [G loss: 0.9255] [C loss: 1.5730]
# [Epoch 1/50] [Batch 800/938] [D loss: 0.6287] [G loss: 0.9863] [C loss: 1.5765]
# [Epoch 1/50] [Batch 900/938] [D loss: 0.6273] [G loss: 0.8504] [C loss: 1.5336]
# [Epoch 2/50] [Batch 0/938] [D loss: 0.6929] [G loss: 0.6481] [C loss: 1.5970]
# [Epoch 2/50] [Batch 100/938] [D loss: 0.6148] [G loss: 1.2000] [C loss: 1.5571]
# [Epoch 2/50] [Batch 200/938] [D loss: 0.7473] [G loss: 0.5221] [C loss: 1.6276]
# [Epoch 2/50] [Batch 300/938] [D loss: 0.6362] [G loss: 0.9238] [C loss: 1.6257]
# [Epoch 2/50] [Batch 400/938] [D loss: 0.6820] [G loss: 0.9890] [C loss: 1.5613]
# [Epoch 2/50] [Batch 500/938] [D loss: 0.6484] [G loss: 0.7826] [C loss: 1.5277]
# [Epoch 2/50] [Batch 600/938] [D loss: 0.6701] [G loss: 0.7498] [C loss: 1.5362]
# [Epoch 2/50] [Batch 700/938] [D loss: 0.6878] [G loss: 0.7143] [C loss: 1.5511]
# [Epoch 2/50] [Batch 800/938] [D loss: 0.6435] [G loss: 0.8874] [C loss: 1.4864]
# [Epoch 2/50] [Batch 900/938] [D loss: 0.6683] [G loss: 0.7657] [C loss: 1.5350]
# [Epoch 3/50] [Batch 0/938] [D loss: 0.6822] [G loss: 0.7421] [C loss: 1.5189]
# [Epoch 3/50] [Batch 100/938] [D loss: 0.6798] [G loss: 0.7460] [C loss: 1.5320]
# [Epoch 3/50] [Batch 200/938] [D loss: 0.6789] [G loss: 0.7010] [C loss: 1.5093]
# [Epoch 3/50] [Batch 300/938] [D loss: 0.6810] [G loss: 0.7104] [C loss: 1.4632]
# [Epoch 3/50] [Batch 400/938] [D loss: 0.6786] [G loss: 0.7681] [C loss: 1.5623]
# [Epoch 3/50] [Batch 500/938] [D loss: 0.6955] [G loss: 0.7096] [C loss: 1.5683]
# [Epoch 3/50] [Batch 600/938] [D loss: 0.6743] [G loss: 0.7174] [C loss: 1.5654]
# [Epoch 3/50] [Batch 700/938] [D loss: 0.6905] [G loss: 0.7152] [C loss: 1.5448]
# [Epoch 3/50] [Batch 800/938] [D loss: 0.6700] [G loss: 0.7357] [C loss: 1.5278]
# [Epoch 3/50] [Batch 900/938] [D loss: 0.6928] [G loss: 0.7450] [C loss: 1.5110]
# [Epoch 4/50] [Batch 0/938] [D loss: 0.6814] [G loss: 0.7376] [C loss: 1.5356]
# [Epoch 4/50] [Batch 100/938] [D loss: 0.6774] [G loss: 0.7422] [C loss: 1.5119]
# [Epoch 4/50] [Batch 200/938] [D loss: 0.6779] [G loss: 0.7303] [C loss: 1.5644]
# [Epoch 4/50] [Batch 300/938] [D loss: 0.6968] [G loss: 0.7187] [C loss: 1.5392]
# [Epoch 4/50] [Batch 400/938] [D loss: 0.6739] [G loss: 0.7432] [C loss: 1.5368]
# [Epoch 4/50] [Batch 500/938] [D loss: 0.6709] [G loss: 0.7510] [C loss: 1.5281]
# [Epoch 4/50] [Batch 600/938] [D loss: 0.6880] [G loss: 0.7172] [C loss: 1.5489]
# [Epoch 4/50] [Batch 700/938] [D loss: 0.6878] [G loss: 0.7249] [C loss: 1.5262]
# [Epoch 4/50] [Batch 800/938] [D loss: 0.6956] [G loss: 0.6927] [C loss: 1.5244]
# [Epoch 4/50] [Batch 900/938] [D loss: 0.6933] [G loss: 0.7124] [C loss: 1.5232]
# [Epoch 5/50] [Batch 0/938] [D loss: 0.6802] [G loss: 0.7124] [C loss: 1.5824]
# [Epoch 5/50] [Batch 100/938] [D loss: 0.6873] [G loss: 0.7172] [C loss: 1.5519]
# [Epoch 5/50] [Batch 200/938] [D loss: 0.6791] [G loss: 0.7213] [C loss: 1.5337]
# [Epoch 5/50] [Batch 300/938] [D loss: 0.6941] [G loss: 0.7250] [C loss: 1.4933]
# [Epoch 5/50] [Batch 400/938] [D loss: 0.6850] [G loss: 0.7146] [C loss: 1.5281]
# [Epoch 5/50] [Batch 500/938] [D loss: 0.6981] [G loss: 0.7192] [C loss: 1.5206]
# [Epoch 5/50] [Batch 600/938] [D loss: 0.6970] [G loss: 0.7230] [C loss: 1.5128]
# [Epoch 5/50] [Batch 700/938] [D loss: 0.6768] [G loss: 0.7522] [C loss: 1.5098]
# [Epoch 5/50] [Batch 800/938] [D loss: 0.6928] [G loss: 0.6937] [C loss: 1.5199]
# [Epoch 5/50] [Batch 900/938] [D loss: 0.6952] [G loss: 0.7233] [C loss: 1.4934]
# [Epoch 6/50] [Batch 0/938] [D loss: 0.6909] [G loss: 0.7046] [C loss: 1.4939]
# [Epoch 6/50] [Batch 100/938] [D loss: 0.6893] [G loss: 0.6948] [C loss: 1.5818]
# [Epoch 6/50] [Batch 200/938] [D loss: 0.6885] [G loss: 0.7153] [C loss: 1.5149]
# [Epoch 6/50] [Batch 300/938] [D loss: 0.6991] [G loss: 0.7204] [C loss: 1.5249]
# [Epoch 6/50] [Batch 400/938] [D loss: 0.6947] [G loss: 0.7006] [C loss: 1.5138]
# [Epoch 6/50] [Batch 500/938] [D loss: 0.6929] [G loss: 0.7233] [C loss: 1.5093]
# [Epoch 6/50] [Batch 600/938] [D loss: 0.6902] [G loss: 0.7239] [C loss: 1.5344]
# [Epoch 6/50] [Batch 700/938] [D loss: 0.6874] [G loss: 0.7020] [C loss: 1.5631]
# [Epoch 6/50] [Batch 800/938] [D loss: 0.6924] [G loss: 0.7013] [C loss: 1.4842]
# [Epoch 6/50] [Batch 900/938] [D loss: 0.6983] [G loss: 0.6986] [C loss: 1.5413]
# [Epoch 7/50] [Batch 0/938] [D loss: 0.6841] [G loss: 0.7082] [C loss: 1.4965]
# [Epoch 7/50] [Batch 100/938] [D loss: 0.6847] [G loss: 0.7282] [C loss: 1.5483]
# [Epoch 7/50] [Batch 200/938] [D loss: 0.6835] [G loss: 0.6934] [C loss: 1.4955]
# [Epoch 7/50] [Batch 300/938] [D loss: 0.6914] [G loss: 0.6896] [C loss: 1.4824]
# [Epoch 7/50] [Batch 400/938] [D loss: 0.6861] [G loss: 0.7497] [C loss: 1.5271]
# [Epoch 7/50] [Batch 500/938] [D loss: 0.6964] [G loss: 0.6885] [C loss: 1.5383]
# [Epoch 7/50] [Batch 600/938] [D loss: 0.6974] [G loss: 0.6959] [C loss: 1.4991]
# [Epoch 7/50] [Batch 700/938] [D loss: 0.6850] [G loss: 0.7012] [C loss: 1.4771]
# [Epoch 7/50] [Batch 800/938] [D loss: 0.6968] [G loss: 0.7266] [C loss: 1.4926]
# [Epoch 7/50] [Batch 900/938] [D loss: 0.6988] [G loss: 0.6964] [C loss: 1.4970]
# [Epoch 8/50] [Batch 0/938] [D loss: 0.7009] [G loss: 0.7342] [C loss: 1.5332]
# [Epoch 8/50] [Batch 100/938] [D loss: 0.6951] [G loss: 0.7056] [C loss: 1.4925]
# [Epoch 8/50] [Batch 200/938] [D loss: 0.6903] [G loss: 0.7181] [C loss: 1.5209]
# [Epoch 8/50] [Batch 300/938] [D loss: 0.6869] [G loss: 0.7073] [C loss: 1.5208]
# [Epoch 8/50] [Batch 400/938] [D loss: 0.6952] [G loss: 0.7044] [C loss: 1.4750]
# [Epoch 8/50] [Batch 500/938] [D loss: 0.6858] [G loss: 0.6899] [C loss: 1.5157]
# [Epoch 8/50] [Batch 600/938] [D loss: 0.6888] [G loss: 0.7229] [C loss: 1.5011]
# [Epoch 8/50] [Batch 700/938] [D loss: 0.6931] [G loss: 0.7072] [C loss: 1.5154]
# [Epoch 8/50] [Batch 800/938] [D loss: 0.6934] [G loss: 0.7010] [C loss: 1.5323]
# [Epoch 8/50] [Batch 900/938] [D loss: 0.6851] [G loss: 0.7072] [C loss: 1.5094]
# [Epoch 9/50] [Batch 0/938] [D loss: 0.6905] [G loss: 0.7185] [C loss: 1.4779]
# [Epoch 9/50] [Batch 100/938] [D loss: 0.6966] [G loss: 0.7013] [C loss: 1.5177]
# [Epoch 9/50] [Batch 200/938] [D loss: 0.6938] [G loss: 0.7123] [C loss: 1.4703]
# [Epoch 9/50] [Batch 300/938] [D loss: 0.6882] [G loss: 0.7163] [C loss: 1.5477]
# [Epoch 9/50] [Batch 400/938] [D loss: 0.6857] [G loss: 0.7199] [C loss: 1.4678]
# [Epoch 9/50] [Batch 500/938] [D loss: 0.6870] [G loss: 0.6951] [C loss: 1.5226]
# [Epoch 9/50] [Batch 600/938] [D loss: 0.6810] [G loss: 0.7024] [C loss: 1.4878]
# [Epoch 9/50] [Batch 700/938] [D loss: 0.6923] [G loss: 0.6952] [C loss: 1.4892]
# [Epoch 9/50] [Batch 800/938] [D loss: 0.6973] [G loss: 0.7264] [C loss: 1.5151]
# [Epoch 9/50] [Batch 900/938] [D loss: 0.6918] [G loss: 0.6885] [C loss: 1.4701]
# [Epoch 10/50] [Batch 0/938] [D loss: 0.6863] [G loss: 0.7238] [C loss: 1.4906]
# [Epoch 10/50] [Batch 100/938] [D loss: 0.6926] [G loss: 0.7126] [C loss: 1.5143]
# [Epoch 10/50] [Batch 200/938] [D loss: 0.6925] [G loss: 0.6963] [C loss: 1.5194]
# [Epoch 10/50] [Batch 300/938] [D loss: 0.6960] [G loss: 0.7087] [C loss: 1.4624]
# [Epoch 10/50] [Batch 400/938] [D loss: 0.6959] [G loss: 0.6920] [C loss: 1.4910]
# [Epoch 10/50] [Batch 500/938] [D loss: 0.6946] [G loss: 0.7024] [C loss: 1.5137]
# [Epoch 10/50] [Batch 600/938] [D loss: 0.6921] [G loss: 0.7208] [C loss: 1.4696]
# [Epoch 10/50] [Batch 700/938] [D loss: 0.6873] [G loss: 0.6982] [C loss: 1.5313]
# [Epoch 10/50] [Batch 800/938] [D loss: 0.6968] [G loss: 0.7069] [C loss: 1.4783]
# [Epoch 10/50] [Batch 900/938] [D loss: 0.6933] [G loss: 0.6867] [C loss: 1.4785]
# [Epoch 11/50] [Batch 0/938] [D loss: 0.6941] [G loss: 0.7014] [C loss: 1.5022]
# [Epoch 11/50] [Batch 100/938] [D loss: 0.6924] [G loss: 0.7124] [C loss: 1.5152]
# [Epoch 11/50] [Batch 200/938] [D loss: 0.6942] [G loss: 0.6996] [C loss: 1.4956]
# [Epoch 11/50] [Batch 300/938] [D loss: 0.7028] [G loss: 0.6780] [C loss: 1.4754]
# [Epoch 11/50] [Batch 400/938] [D loss: 0.6866] [G loss: 0.7178] [C loss: 1.5190]
# [Epoch 11/50] [Batch 500/938] [D loss: 0.6912] [G loss: 0.7071] [C loss: 1.4910]
# [Epoch 11/50] [Batch 600/938] [D loss: 0.6923] [G loss: 0.6997] [C loss: 1.4653]
# [Epoch 11/50] [Batch 700/938] [D loss: 0.6985] [G loss: 0.7059] [C loss: 1.5014]
# [Epoch 11/50] [Batch 800/938] [D loss: 0.6948] [G loss: 0.7225] [C loss: 1.4878]
# [Epoch 11/50] [Batch 900/938] [D loss: 0.6947] [G loss: 0.7120] [C loss: 1.4861]
# [Epoch 12/50] [Batch 0/938] [D loss: 0.6934] [G loss: 0.7179] [C loss: 1.5221]
# [Epoch 12/50] [Batch 100/938] [D loss: 0.6903] [G loss: 0.7096] [C loss: 1.4639]
# [Epoch 12/50] [Batch 200/938] [D loss: 0.6971] [G loss: 0.7009] [C loss: 1.4883]
# [Epoch 12/50] [Batch 300/938] [D loss: 0.7003] [G loss: 0.6909] [C loss: 1.4716]
# [Epoch 12/50] [Batch 400/938] [D loss: 0.6954] [G loss: 0.6984] [C loss: 1.5076]
# [Epoch 12/50] [Batch 500/938] [D loss: 0.7000] [G loss: 0.7004] [C loss: 1.4637]
# [Epoch 12/50] [Batch 600/938] [D loss: 0.6939] [G loss: 0.7011] [C loss: 1.4995]
# [Epoch 12/50] [Batch 700/938] [D loss: 0.6911] [G loss: 0.7073] [C loss: 1.5191]
# [Epoch 12/50] [Batch 800/938] [D loss: 0.6899] [G loss: 0.6962] [C loss: 1.5078]
# [Epoch 12/50] [Batch 900/938] [D loss: 0.6942] [G loss: 0.7216] [C loss: 1.4931]
# [Epoch 13/50] [Batch 0/938] [D loss: 0.6934] [G loss: 0.6898] [C loss: 1.4783]
# [Epoch 13/50] [Batch 100/938] [D loss: 0.6911] [G loss: 0.7070] [C loss: 1.5179]
# [Epoch 13/50] [Batch 200/938] [D loss: 0.6946] [G loss: 0.7127] [C loss: 1.4778]
# [Epoch 13/50] [Batch 300/938] [D loss: 0.6967] [G loss: 0.7043] [C loss: 1.5085]
# [Epoch 13/50] [Batch 400/938] [D loss: 0.6927] [G loss: 0.6947] [C loss: 1.5201]
# [Epoch 13/50] [Batch 500/938] [D loss: 0.6868] [G loss: 0.6927] [C loss: 1.4930]
# [Epoch 13/50] [Batch 600/938] [D loss: 0.6928] [G loss: 0.6965] [C loss: 1.4775]
# [Epoch 13/50] [Batch 700/938] [D loss: 0.6900] [G loss: 0.7038] [C loss: 1.4942]
# [Epoch 13/50] [Batch 800/938] [D loss: 0.6866] [G loss: 0.7018] [C loss: 1.4713]
# [Epoch 13/50] [Batch 900/938] [D loss: 0.6906] [G loss: 0.6929] [C loss: 1.4816]
# [Epoch 14/50] [Batch 0/938] [D loss: 0.6966] [G loss: 0.7100] [C loss: 1.4839]
# [Epoch 14/50] [Batch 100/938] [D loss: 0.6936] [G loss: 0.7069] [C loss: 1.5225]
# [Epoch 14/50] [Batch 200/938] [D loss: 0.6846] [G loss: 0.6930] [C loss: 1.5279]
# [Epoch 14/50] [Batch 300/938] [D loss: 0.6973] [G loss: 0.6866] [C loss: 1.4732]
# [Epoch 14/50] [Batch 400/938] [D loss: 0.6857] [G loss: 0.7042] [C loss: 1.5241]
# [Epoch 14/50] [Batch 500/938] [D loss: 0.6940] [G loss: 0.7125] [C loss: 1.4676]
# [Epoch 14/50] [Batch 600/938] [D loss: 0.6940] [G loss: 0.7060] [C loss: 1.4786]
# [Epoch 14/50] [Batch 700/938] [D loss: 0.6963] [G loss: 0.7125] [C loss: 1.4974]
# [Epoch 14/50] [Batch 800/938] [D loss: 0.6911] [G loss: 0.7033] [C loss: 1.5021]
# [Epoch 14/50] [Batch 900/938] [D loss: 0.6975] [G loss: 0.6862] [C loss: 1.5062]
# [Epoch 15/50] [Batch 0/938] [D loss: 0.6942] [G loss: 0.6997] [C loss: 1.4777]
# [Epoch 15/50] [Batch 100/938] [D loss: 0.6958] [G loss: 0.6922] [C loss: 1.5364]
# [Epoch 15/50] [Batch 200/938] [D loss: 0.6942] [G loss: 0.7231] [C loss: 1.4942]
# [Epoch 15/50] [Batch 300/938] [D loss: 0.6976] [G loss: 0.7029] [C loss: 1.4746]
# [Epoch 15/50] [Batch 400/938] [D loss: 0.6982] [G loss: 0.6913] [C loss: 1.4907]
# [Epoch 15/50] [Batch 500/938] [D loss: 0.6899] [G loss: 0.7196] [C loss: 1.4780]
# [Epoch 15/50] [Batch 600/938] [D loss: 0.6936] [G loss: 0.7107] [C loss: 1.4814]
# [Epoch 15/50] [Batch 700/938] [D loss: 0.6991] [G loss: 0.6882] [C loss: 1.4639]
# [Epoch 15/50] [Batch 800/938] [D loss: 0.6863] [G loss: 0.6899] [C loss: 1.4805]
# [Epoch 15/50] [Batch 900/938] [D loss: 0.6936] [G loss: 0.6929] [C loss: 1.4919]
# [Epoch 16/50] [Batch 0/938] [D loss: 0.6993] [G loss: 0.6789] [C loss: 1.4930]
# [Epoch 16/50] [Batch 100/938] [D loss: 0.6929] [G loss: 0.6926] [C loss: 1.4777]
# [Epoch 16/50] [Batch 200/938] [D loss: 0.6919] [G loss: 0.7052] [C loss: 1.4918]
# [Epoch 16/50] [Batch 300/938] [D loss: 0.6917] [G loss: 0.7087] [C loss: 1.4887]
# [Epoch 16/50] [Batch 400/938] [D loss: 0.6816] [G loss: 0.7081] [C loss: 1.5009]
# [Epoch 16/50] [Batch 500/938] [D loss: 0.6967] [G loss: 0.7023] [C loss: 1.5094]
# [Epoch 16/50] [Batch 600/938] [D loss: 0.6922] [G loss: 0.7210] [C loss: 1.5353]
# [Epoch 16/50] [Batch 700/938] [D loss: 0.6995] [G loss: 0.7167] [C loss: 1.4713]
# [Epoch 16/50] [Batch 800/938] [D loss: 0.7018] [G loss: 0.7027] [C loss: 1.5095]
# [Epoch 16/50] [Batch 900/938] [D loss: 0.6928] [G loss: 0.6987] [C loss: 1.5257]
# [Epoch 17/50] [Batch 0/938] [D loss: 0.6964] [G loss: 0.7143] [C loss: 1.5568]
# [Epoch 17/50] [Batch 100/938] [D loss: 0.6906] [G loss: 0.7075] [C loss: 1.4612]
# [Epoch 17/50] [Batch 200/938] [D loss: 0.6887] [G loss: 0.6992] [C loss: 1.5040]
# [Epoch 17/50] [Batch 300/938] [D loss: 0.6996] [G loss: 0.6998] [C loss: 1.4992]
# [Epoch 17/50] [Batch 400/938] [D loss: 0.6918] [G loss: 0.6844] [C loss: 1.4774]
# [Epoch 17/50] [Batch 500/938] [D loss: 0.6909] [G loss: 0.6973] [C loss: 1.4728]
# [Epoch 17/50] [Batch 600/938] [D loss: 0.6929] [G loss: 0.6958] [C loss: 1.4696]
# [Epoch 17/50] [Batch 700/938] [D loss: 0.6919] [G loss: 0.6941] [C loss: 1.4738]
# [Epoch 17/50] [Batch 800/938] [D loss: 0.6919] [G loss: 0.6830] [C loss: 1.5045]
# [Epoch 17/50] [Batch 900/938] [D loss: 0.6927] [G loss: 0.6978] [C loss: 1.5282]
# [Epoch 18/50] [Batch 0/938] [D loss: 0.6924] [G loss: 0.6928] [C loss: 1.4942]
# [Epoch 18/50] [Batch 100/938] [D loss: 0.6942] [G loss: 0.7083] [C loss: 1.4972]
# [Epoch 18/50] [Batch 200/938] [D loss: 0.6902] [G loss: 0.6932] [C loss: 1.4715]
# [Epoch 18/50] [Batch 300/938] [D loss: 0.6908] [G loss: 0.7157] [C loss: 1.4939]
# [Epoch 18/50] [Batch 400/938] [D loss: 0.6882] [G loss: 0.6927] [C loss: 1.4803]
# [Epoch 18/50] [Batch 500/938] [D loss: 0.6934] [G loss: 0.7184] [C loss: 1.4793]
# [Epoch 18/50] [Batch 600/938] [D loss: 0.6934] [G loss: 0.7072] [C loss: 1.4769]
# [Epoch 18/50] [Batch 700/938] [D loss: 0.6918] [G loss: 0.6936] [C loss: 1.4829]
# [Epoch 18/50] [Batch 800/938] [D loss: 0.6931] [G loss: 0.6984] [C loss: 1.5344]
# [Epoch 18/50] [Batch 900/938] [D loss: 0.6890] [G loss: 0.6927] [C loss: 1.5106]
# [Epoch 19/50] [Batch 0/938] [D loss: 0.6960] [G loss: 0.7001] [C loss: 1.5587]
# [Epoch 19/50] [Batch 100/938] [D loss: 0.6889] [G loss: 0.6818] [C loss: 1.5243]
# [Epoch 19/50] [Batch 200/938] [D loss: 0.6932] [G loss: 0.6937] [C loss: 1.4854]
# [Epoch 19/50] [Batch 300/938] [D loss: 0.6940] [G loss: 0.7009] [C loss: 1.4615]
# [Epoch 19/50] [Batch 400/938] [D loss: 0.6959] [G loss: 0.6997] [C loss: 1.4766]
# [Epoch 19/50] [Batch 500/938] [D loss: 0.6904] [G loss: 0.6909] [C loss: 1.4848]
# [Epoch 19/50] [Batch 600/938] [D loss: 0.6936] [G loss: 0.7049] [C loss: 1.4924]
# [Epoch 19/50] [Batch 700/938] [D loss: 0.6982] [G loss: 0.7085] [C loss: 1.4613]
# [Epoch 19/50] [Batch 800/938] [D loss: 0.6889] [G loss: 0.6967] [C loss: 1.4731]
# [Epoch 19/50] [Batch 900/938] [D loss: 0.6892] [G loss: 0.6866] [C loss: 1.4968]
# [Epoch 20/50] [Batch 0/938] [D loss: 0.6967] [G loss: 0.6893] [C loss: 1.4681]
# [Epoch 20/50] [Batch 100/938] [D loss: 0.6978] [G loss: 0.6960] [C loss: 1.5045]
# [Epoch 20/50] [Batch 200/938] [D loss: 0.6951] [G loss: 0.7049] [C loss: 1.4628]
# [Epoch 20/50] [Batch 300/938] [D loss: 0.6935] [G loss: 0.6972] [C loss: 1.4772]
# [Epoch 20/50] [Batch 400/938] [D loss: 0.6918] [G loss: 0.6983] [C loss: 1.4753]
# [Epoch 20/50] [Batch 500/938] [D loss: 0.6929] [G loss: 0.7069] [C loss: 1.4791]
# [Epoch 20/50] [Batch 600/938] [D loss: 0.6944] [G loss: 0.6912] [C loss: 1.4886]
# [Epoch 20/50] [Batch 700/938] [D loss: 0.6912] [G loss: 0.7031] [C loss: 1.4832]
# [Epoch 20/50] [Batch 800/938] [D loss: 0.6916] [G loss: 0.6889] [C loss: 1.4843]
# [Epoch 20/50] [Batch 900/938] [D loss: 0.6893] [G loss: 0.6736] [C loss: 1.4766]
# [Epoch 21/50] [Batch 0/938] [D loss: 0.6959] [G loss: 0.6793] [C loss: 1.4799]
# [Epoch 21/50] [Batch 100/938] [D loss: 0.6931] [G loss: 0.6996] [C loss: 1.5095]
# [Epoch 21/50] [Batch 200/938] [D loss: 0.6918] [G loss: 0.7060] [C loss: 1.5221]
# [Epoch 21/50] [Batch 300/938] [D loss: 0.6944] [G loss: 0.6790] [C loss: 1.4911]
# [Epoch 21/50] [Batch 400/938] [D loss: 0.6935] [G loss: 0.6909] [C loss: 1.4683]
# [Epoch 21/50] [Batch 500/938] [D loss: 0.6901] [G loss: 0.6939] [C loss: 1.4627]
# [Epoch 21/50] [Batch 600/938] [D loss: 0.6889] [G loss: 0.7043] [C loss: 1.5092]
# [Epoch 21/50] [Batch 700/938] [D loss: 0.6965] [G loss: 0.7025] [C loss: 1.5103]
# [Epoch 21/50] [Batch 800/938] [D loss: 0.6984] [G loss: 0.6951] [C loss: 1.4624]
# [Epoch 21/50] [Batch 900/938] [D loss: 0.6887] [G loss: 0.7017] [C loss: 1.4782]
# [Epoch 22/50] [Batch 0/938] [D loss: 0.6952] [G loss: 0.6969] [C loss: 1.4771]
# [Epoch 22/50] [Batch 100/938] [D loss: 0.6942] [G loss: 0.7110] [C loss: 1.4908]
# [Epoch 22/50] [Batch 200/938] [D loss: 0.6875] [G loss: 0.6904] [C loss: 1.4861]
# [Epoch 22/50] [Batch 300/938] [D loss: 0.6916] [G loss: 0.7025] [C loss: 1.4931]
# [Epoch 22/50] [Batch 400/938] [D loss: 0.6960] [G loss: 0.7194] [C loss: 1.4616]
# [Epoch 22/50] [Batch 500/938] [D loss: 0.6853] [G loss: 0.6918] [C loss: 1.4772]
# [Epoch 22/50] [Batch 600/938] [D loss: 0.6980] [G loss: 0.6787] [C loss: 1.4636]
# [Epoch 22/50] [Batch 700/938] [D loss: 0.6871] [G loss: 0.7139] [C loss: 1.4904]
# [Epoch 22/50] [Batch 800/938] [D loss: 0.6888] [G loss: 0.6946] [C loss: 1.5133]
# [Epoch 22/50] [Batch 900/938] [D loss: 0.6942] [G loss: 0.7212] [C loss: 1.4984]
# [Epoch 23/50] [Batch 0/938] [D loss: 0.6900] [G loss: 0.6820] [C loss: 1.4775]
# [Epoch 23/50] [Batch 100/938] [D loss: 0.6901] [G loss: 0.6897] [C loss: 1.4612]
# [Epoch 23/50] [Batch 200/938] [D loss: 0.6922] [G loss: 0.6980] [C loss: 1.4625]
# [Epoch 23/50] [Batch 300/938] [D loss: 0.6941] [G loss: 0.7141] [C loss: 1.4992]
# [Epoch 23/50] [Batch 400/938] [D loss: 0.6923] [G loss: 0.7069] [C loss: 1.5114]
# [Epoch 23/50] [Batch 500/938] [D loss: 0.6925] [G loss: 0.6929] [C loss: 1.4761]
# [Epoch 23/50] [Batch 600/938] [D loss: 0.6922] [G loss: 0.6950] [C loss: 1.5240]
# [Epoch 23/50] [Batch 700/938] [D loss: 0.6946] [G loss: 0.6932] [C loss: 1.5469]
# [Epoch 23/50] [Batch 800/938] [D loss: 0.6935] [G loss: 0.6921] [C loss: 1.4922]
# [Epoch 23/50] [Batch 900/938] [D loss: 0.6928] [G loss: 0.7059] [C loss: 1.4922]
# [Epoch 24/50] [Batch 0/938] [D loss: 0.6982] [G loss: 0.7013] [C loss: 1.4623]
# [Epoch 24/50] [Batch 100/938] [D loss: 0.6967] [G loss: 0.6923] [C loss: 1.5094]
# [Epoch 24/50] [Batch 200/938] [D loss: 0.6924] [G loss: 0.7041] [C loss: 1.4767]
# [Epoch 24/50] [Batch 300/938] [D loss: 0.6937] [G loss: 0.6904] [C loss: 1.4961]
# [Epoch 24/50] [Batch 400/938] [D loss: 0.6920] [G loss: 0.7024] [C loss: 1.4968]
# [Epoch 24/50] [Batch 500/938] [D loss: 0.6940] [G loss: 0.7000] [C loss: 1.4701]
# [Epoch 24/50] [Batch 600/938] [D loss: 0.6962] [G loss: 0.7067] [C loss: 1.4951]
# [Epoch 24/50] [Batch 700/938] [D loss: 0.6918] [G loss: 0.6961] [C loss: 1.4944]
# [Epoch 24/50] [Batch 800/938] [D loss: 0.6952] [G loss: 0.7091] [C loss: 1.4783]
# [Epoch 24/50] [Batch 900/938] [D loss: 0.6949] [G loss: 0.6994] [C loss: 1.4695]
# [Epoch 25/50] [Batch 0/938] [D loss: 0.6883] [G loss: 0.7022] [C loss: 1.4935]
# [Epoch 25/50] [Batch 100/938] [D loss: 0.6935] [G loss: 0.7009] [C loss: 1.4968]
# [Epoch 25/50] [Batch 200/938] [D loss: 0.6946] [G loss: 0.7231] [C loss: 1.4701]
# [Epoch 25/50] [Batch 300/938] [D loss: 0.6938] [G loss: 0.6944] [C loss: 1.4612]
# [Epoch 25/50] [Batch 400/938] [D loss: 0.6952] [G loss: 0.6953] [C loss: 1.4935]
# [Epoch 25/50] [Batch 500/938] [D loss: 0.6924] [G loss: 0.6966] [C loss: 1.4684]
# [Epoch 25/50] [Batch 600/938] [D loss: 0.6955] [G loss: 0.6800] [C loss: 1.5354]
# [Epoch 25/50] [Batch 700/938] [D loss: 0.6955] [G loss: 0.7013] [C loss: 1.4954]
# [Epoch 25/50] [Batch 800/938] [D loss: 0.6985] [G loss: 0.6855] [C loss: 1.4720]
# [Epoch 25/50] [Batch 900/938] [D loss: 0.6860] [G loss: 0.6877] [C loss: 1.4829]
# [Epoch 26/50] [Batch 0/938] [D loss: 0.6892] [G loss: 0.6901] [C loss: 1.4803]
# [Epoch 26/50] [Batch 100/938] [D loss: 0.6898] [G loss: 0.7089] [C loss: 1.4616]
# [Epoch 26/50] [Batch 200/938] [D loss: 0.6927] [G loss: 0.7041] [C loss: 1.5106]
# [Epoch 26/50] [Batch 300/938] [D loss: 0.6930] [G loss: 0.7024] [C loss: 1.5181]
# [Epoch 26/50] [Batch 400/938] [D loss: 0.6964] [G loss: 0.6909] [C loss: 1.4881]
# [Epoch 26/50] [Batch 500/938] [D loss: 0.6947] [G loss: 0.6886] [C loss: 1.4762]
# [Epoch 26/50] [Batch 600/938] [D loss: 0.6943] [G loss: 0.6900] [C loss: 1.4901]
# [Epoch 26/50] [Batch 700/938] [D loss: 0.6925] [G loss: 0.6855] [C loss: 1.4639]
# [Epoch 26/50] [Batch 800/938] [D loss: 0.6927] [G loss: 0.7064] [C loss: 1.4622]
# [Epoch 26/50] [Batch 900/938] [D loss: 0.6930] [G loss: 0.6958] [C loss: 1.4752]
# [Epoch 27/50] [Batch 0/938] [D loss: 0.6944] [G loss: 0.6919] [C loss: 1.4770]
# [Epoch 27/50] [Batch 100/938] [D loss: 0.6945] [G loss: 0.6866] [C loss: 1.4807]
# [Epoch 27/50] [Batch 200/938] [D loss: 0.6890] [G loss: 0.7022] [C loss: 1.4864]
# [Epoch 27/50] [Batch 300/938] [D loss: 0.6987] [G loss: 0.7079] [C loss: 1.4735]
# [Epoch 27/50] [Batch 400/938] [D loss: 0.6926] [G loss: 0.6906] [C loss: 1.4646]
# [Epoch 27/50] [Batch 500/938] [D loss: 0.6918] [G loss: 0.6942] [C loss: 1.4983]
# [Epoch 27/50] [Batch 600/938] [D loss: 0.6919] [G loss: 0.6952] [C loss: 1.4983]
# [Epoch 27/50] [Batch 700/938] [D loss: 0.6943] [G loss: 0.6909] [C loss: 1.4813]
# [Epoch 27/50] [Batch 800/938] [D loss: 0.6944] [G loss: 0.6951] [C loss: 1.4617]
# [Epoch 27/50] [Batch 900/938] [D loss: 0.6886] [G loss: 0.6971] [C loss: 1.4773]
# [Epoch 28/50] [Batch 0/938] [D loss: 0.6941] [G loss: 0.6948] [C loss: 1.4612]
# [Epoch 28/50] [Batch 100/938] [D loss: 0.6942] [G loss: 0.7022] [C loss: 1.4813]
# [Epoch 28/50] [Batch 200/938] [D loss: 0.6968] [G loss: 0.6888] [C loss: 1.4670]
# [Epoch 28/50] [Batch 300/938] [D loss: 0.6938] [G loss: 0.6951] [C loss: 1.5194]
# [Epoch 28/50] [Batch 400/938] [D loss: 0.6961] [G loss: 0.6886] [C loss: 1.4613]
# [Epoch 28/50] [Batch 500/938] [D loss: 0.6915] [G loss: 0.7002] [C loss: 1.4621]
# [Epoch 28/50] [Batch 600/938] [D loss: 0.6936] [G loss: 0.6977] [C loss: 1.4771]
# [Epoch 28/50] [Batch 700/938] [D loss: 0.6906] [G loss: 0.6868] [C loss: 1.4768]
# [Epoch 28/50] [Batch 800/938] [D loss: 0.6957] [G loss: 0.7016] [C loss: 1.4950]
# [Epoch 28/50] [Batch 900/938] [D loss: 0.6937] [G loss: 0.7006] [C loss: 1.4771]
# [Epoch 29/50] [Batch 0/938] [D loss: 0.6954] [G loss: 0.6823] [C loss: 1.4818]
# [Epoch 29/50] [Batch 100/938] [D loss: 0.7013] [G loss: 0.6840] [C loss: 1.4648]
# [Epoch 29/50] [Batch 200/938] [D loss: 0.6957] [G loss: 0.6885] [C loss: 1.4752]
# [Epoch 29/50] [Batch 300/938] [D loss: 0.6935] [G loss: 0.7102] [C loss: 1.4702]
# [Epoch 29/50] [Batch 400/938] [D loss: 0.7024] [G loss: 0.7002] [C loss: 1.4696]
# [Epoch 29/50] [Batch 500/938] [D loss: 0.6935] [G loss: 0.6923] [C loss: 1.4768]
# [Epoch 29/50] [Batch 600/938] [D loss: 0.6944] [G loss: 0.6844] [C loss: 1.4635]
# [Epoch 29/50] [Batch 700/938] [D loss: 0.6971] [G loss: 0.7033] [C loss: 1.4612]
# [Epoch 29/50] [Batch 800/938] [D loss: 0.6918] [G loss: 0.7108] [C loss: 1.4914]
# [Epoch 29/50] [Batch 900/938] [D loss: 0.6903] [G loss: 0.7154] [C loss: 1.4734]
# [Epoch 30/50] [Batch 0/938] [D loss: 0.7009] [G loss: 0.6895] [C loss: 1.4624]
# [Epoch 30/50] [Batch 100/938] [D loss: 0.6961] [G loss: 0.7062] [C loss: 1.4768]
# [Epoch 30/50] [Batch 200/938] [D loss: 0.6884] [G loss: 0.6919] [C loss: 1.4715]
# [Epoch 30/50] [Batch 300/938] [D loss: 0.6964] [G loss: 0.7086] [C loss: 1.4781]
# [Epoch 30/50] [Batch 400/938] [D loss: 0.6983] [G loss: 0.6891] [C loss: 1.4613]
# [Epoch 30/50] [Batch 500/938] [D loss: 0.6970] [G loss: 0.6964] [C loss: 1.5079]
# [Epoch 30/50] [Batch 600/938] [D loss: 0.6908] [G loss: 0.7081] [C loss: 1.4660]
# [Epoch 30/50] [Batch 700/938] [D loss: 0.6893] [G loss: 0.6966] [C loss: 1.4768]
# [Epoch 30/50] [Batch 800/938] [D loss: 0.6869] [G loss: 0.6959] [C loss: 1.4770]
# [Epoch 30/50] [Batch 900/938] [D loss: 0.6923] [G loss: 0.6946] [C loss: 1.4940]
# [Epoch 31/50] [Batch 0/938] [D loss: 0.6896] [G loss: 0.6930] [C loss: 1.5019]
# [Epoch 31/50] [Batch 100/938] [D loss: 0.6884] [G loss: 0.7010] [C loss: 1.4618]
# [Epoch 31/50] [Batch 200/938] [D loss: 0.6949] [G loss: 0.7087] [C loss: 1.4940]
# [Epoch 31/50] [Batch 300/938] [D loss: 0.6896] [G loss: 0.6964] [C loss: 1.4659]
# [Epoch 31/50] [Batch 400/938] [D loss: 0.6932] [G loss: 0.6914] [C loss: 1.5236]
# [Epoch 31/50] [Batch 500/938] [D loss: 0.6899] [G loss: 0.6851] [C loss: 1.5335]
# [Epoch 31/50] [Batch 600/938] [D loss: 0.6911] [G loss: 0.7007] [C loss: 1.4619]
# [Epoch 31/50] [Batch 700/938] [D loss: 0.6912] [G loss: 0.7059] [C loss: 1.4619]
# [Epoch 31/50] [Batch 800/938] [D loss: 0.6924] [G loss: 0.6874] [C loss: 1.4657]
# [Epoch 31/50] [Batch 900/938] [D loss: 0.6907] [G loss: 0.6995] [C loss: 1.4950]
# [Epoch 32/50] [Batch 0/938] [D loss: 0.6939] [G loss: 0.6872] [C loss: 1.5080]
# [Epoch 32/50] [Batch 100/938] [D loss: 0.6934] [G loss: 0.6865] [C loss: 1.4826]
# [Epoch 32/50] [Batch 200/938] [D loss: 0.6935] [G loss: 0.6892] [C loss: 1.4921]
# [Epoch 32/50] [Batch 300/938] [D loss: 0.6893] [G loss: 0.7030] [C loss: 1.4920]
# [Epoch 32/50] [Batch 400/938] [D loss: 0.6885] [G loss: 0.7040] [C loss: 1.5051]
# [Epoch 32/50] [Batch 500/938] [D loss: 0.6899] [G loss: 0.7033] [C loss: 1.4764]
# [Epoch 32/50] [Batch 600/938] [D loss: 0.6957] [G loss: 0.6922] [C loss: 1.4793]
# [Epoch 32/50] [Batch 700/938] [D loss: 0.6937] [G loss: 0.6933] [C loss: 1.4781]
# [Epoch 32/50] [Batch 800/938] [D loss: 0.6943] [G loss: 0.6956] [C loss: 1.4757]
# [Epoch 32/50] [Batch 900/938] [D loss: 0.6931] [G loss: 0.6927] [C loss: 1.4820]
# [Epoch 33/50] [Batch 0/938] [D loss: 0.6921] [G loss: 0.6817] [C loss: 1.4652]
# [Epoch 33/50] [Batch 100/938] [D loss: 0.6941] [G loss: 0.6906] [C loss: 1.4824]
# [Epoch 33/50] [Batch 200/938] [D loss: 0.6900] [G loss: 0.7037] [C loss: 1.4882]
# [Epoch 33/50] [Batch 300/938] [D loss: 0.6904] [G loss: 0.6928] [C loss: 1.4641]
# [Epoch 33/50] [Batch 400/938] [D loss: 0.6943] [G loss: 0.7062] [C loss: 1.5079]
# [Epoch 33/50] [Batch 500/938] [D loss: 0.6900] [G loss: 0.7089] [C loss: 1.4884]
# [Epoch 33/50] [Batch 600/938] [D loss: 0.6902] [G loss: 0.6971] [C loss: 1.4644]
# [Epoch 33/50] [Batch 700/938] [D loss: 0.6904] [G loss: 0.7028] [C loss: 1.5064]
# [Epoch 33/50] [Batch 800/938] [D loss: 0.6976] [G loss: 0.6924] [C loss: 1.4765]
# [Epoch 33/50] [Batch 900/938] [D loss: 0.6945] [G loss: 0.7052] [C loss: 1.4770]
# [Epoch 34/50] [Batch 0/938] [D loss: 0.6914] [G loss: 0.6921] [C loss: 1.4931]
# [Epoch 34/50] [Batch 100/938] [D loss: 0.6924] [G loss: 0.6983] [C loss: 1.4696]
# [Epoch 34/50] [Batch 200/938] [D loss: 0.6969] [G loss: 0.6748] [C loss: 1.5276]
# [Epoch 34/50] [Batch 300/938] [D loss: 0.6966] [G loss: 0.6808] [C loss: 1.4917]
# [Epoch 34/50] [Batch 400/938] [D loss: 0.6913] [G loss: 0.6945] [C loss: 1.4781]
# [Epoch 34/50] [Batch 500/938] [D loss: 0.6924] [G loss: 0.6896] [C loss: 1.4769]
# [Epoch 34/50] [Batch 600/938] [D loss: 0.6898] [G loss: 0.6956] [C loss: 1.5177]
# [Epoch 34/50] [Batch 700/938] [D loss: 0.6930] [G loss: 0.6976] [C loss: 1.4769]
# [Epoch 34/50] [Batch 800/938] [D loss: 0.6935] [G loss: 0.7088] [C loss: 1.4915]
# [Epoch 34/50] [Batch 900/938] [D loss: 0.6970] [G loss: 0.6997] [C loss: 1.4798]
# [Epoch 35/50] [Batch 0/938] [D loss: 0.6934] [G loss: 0.7072] [C loss: 1.4924]
# [Epoch 35/50] [Batch 100/938] [D loss: 0.6890] [G loss: 0.6941] [C loss: 1.4947]
# [Epoch 35/50] [Batch 200/938] [D loss: 0.6934] [G loss: 0.6978] [C loss: 1.4622]
# [Epoch 35/50] [Batch 300/938] [D loss: 0.6920] [G loss: 0.6803] [C loss: 1.4617]
# [Epoch 35/50] [Batch 400/938] [D loss: 0.6942] [G loss: 0.7062] [C loss: 1.4631]
# [Epoch 35/50] [Batch 500/938] [D loss: 0.6945] [G loss: 0.6954] [C loss: 1.5081]
# [Epoch 35/50] [Batch 600/938] [D loss: 0.6996] [G loss: 0.6918] [C loss: 1.4936]
# [Epoch 35/50] [Batch 700/938] [D loss: 0.6917] [G loss: 0.6932] [C loss: 1.4743]
# [Epoch 35/50] [Batch 800/938] [D loss: 0.6915] [G loss: 0.7008] [C loss: 1.4616]
# [Epoch 35/50] [Batch 900/938] [D loss: 0.6969] [G loss: 0.6940] [C loss: 1.5078]
# [Epoch 36/50] [Batch 0/938] [D loss: 0.6899] [G loss: 0.6922] [C loss: 1.4612]
# [Epoch 36/50] [Batch 100/938] [D loss: 0.6905] [G loss: 0.6976] [C loss: 1.4613]
# [Epoch 36/50] [Batch 200/938] [D loss: 0.6934] [G loss: 0.7021] [C loss: 1.4740]
# [Epoch 36/50] [Batch 300/938] [D loss: 0.6894] [G loss: 0.7097] [C loss: 1.4612]
# [Epoch 36/50] [Batch 400/938] [D loss: 0.6885] [G loss: 0.6861] [C loss: 1.4631]
# [Epoch 36/50] [Batch 500/938] [D loss: 0.6961] [G loss: 0.6948] [C loss: 1.4768]
# [Epoch 36/50] [Batch 600/938] [D loss: 0.6963] [G loss: 0.6948] [C loss: 1.4612]
# [Epoch 36/50] [Batch 700/938] [D loss: 0.6935] [G loss: 0.6963] [C loss: 1.4931]
# [Epoch 36/50] [Batch 800/938] [D loss: 0.6932] [G loss: 0.7117] [C loss: 1.4801]
# [Epoch 36/50] [Batch 900/938] [D loss: 0.6952] [G loss: 0.6987] [C loss: 1.4629]
# [Epoch 37/50] [Batch 0/938] [D loss: 0.6921] [G loss: 0.6854] [C loss: 1.4613]
# [Epoch 37/50] [Batch 100/938] [D loss: 0.6895] [G loss: 0.7047] [C loss: 1.4761]
# [Epoch 37/50] [Batch 200/938] [D loss: 0.6904] [G loss: 0.6961] [C loss: 1.4944]
# [Epoch 37/50] [Batch 300/938] [D loss: 0.6950] [G loss: 0.6925] [C loss: 1.4769]
# [Epoch 37/50] [Batch 400/938] [D loss: 0.6954] [G loss: 0.6972] [C loss: 1.4612]
# [Epoch 37/50] [Batch 500/938] [D loss: 0.6912] [G loss: 0.6909] [C loss: 1.4799]
# [Epoch 37/50] [Batch 600/938] [D loss: 0.6931] [G loss: 0.6882] [C loss: 1.4942]
# [Epoch 37/50] [Batch 700/938] [D loss: 0.6920] [G loss: 0.7074] [C loss: 1.4784]
# [Epoch 37/50] [Batch 800/938] [D loss: 0.6938] [G loss: 0.6975] [C loss: 1.4612]
# [Epoch 37/50] [Batch 900/938] [D loss: 0.6837] [G loss: 0.7232] [C loss: 1.4840]
# [Epoch 38/50] [Batch 0/938] [D loss: 0.6930] [G loss: 0.6910] [C loss: 1.4669]
# [Epoch 38/50] [Batch 100/938] [D loss: 0.6939] [G loss: 0.7008] [C loss: 1.4783]
# [Epoch 38/50] [Batch 200/938] [D loss: 0.6910] [G loss: 0.7152] [C loss: 1.4618]
# [Epoch 38/50] [Batch 300/938] [D loss: 0.6938] [G loss: 0.6922] [C loss: 1.4613]
# [Epoch 38/50] [Batch 400/938] [D loss: 0.6955] [G loss: 0.7014] [C loss: 1.4633]
# [Epoch 38/50] [Batch 500/938] [D loss: 0.6935] [G loss: 0.7024] [C loss: 1.4926]
# [Epoch 38/50] [Batch 600/938] [D loss: 0.6984] [G loss: 0.7090] [C loss: 1.4768]
# [Epoch 38/50] [Batch 700/938] [D loss: 0.6939] [G loss: 0.6980] [C loss: 1.4905]
# [Epoch 38/50] [Batch 800/938] [D loss: 0.6923] [G loss: 0.6992] [C loss: 1.4928]
# [Epoch 38/50] [Batch 900/938] [D loss: 0.6908] [G loss: 0.7013] [C loss: 1.4882]
# [Epoch 39/50] [Batch 0/938] [D loss: 0.6923] [G loss: 0.6976] [C loss: 1.4785]
# [Epoch 39/50] [Batch 100/938] [D loss: 0.6940] [G loss: 0.6876] [C loss: 1.4779]
# [Epoch 39/50] [Batch 200/938] [D loss: 0.6866] [G loss: 0.7019] [C loss: 1.4768]
# [Epoch 39/50] [Batch 300/938] [D loss: 0.6945] [G loss: 0.6993] [C loss: 1.4612]
# [Epoch 39/50] [Batch 400/938] [D loss: 0.6946] [G loss: 0.6983] [C loss: 1.4681]
# [Epoch 39/50] [Batch 500/938] [D loss: 0.6952] [G loss: 0.6897] [C loss: 1.4616]
# [Epoch 39/50] [Batch 600/938] [D loss: 0.6908] [G loss: 0.6928] [C loss: 1.4976]
# [Epoch 39/50] [Batch 700/938] [D loss: 0.6929] [G loss: 0.7088] [C loss: 1.4681]
# [Epoch 39/50] [Batch 800/938] [D loss: 0.6901] [G loss: 0.7052] [C loss: 1.5080]
# [Epoch 39/50] [Batch 900/938] [D loss: 0.6930] [G loss: 0.7049] [C loss: 1.4682]
# [Epoch 40/50] [Batch 0/938] [D loss: 0.6923] [G loss: 0.6952] [C loss: 1.4619]
# [Epoch 40/50] [Batch 100/938] [D loss: 0.6889] [G loss: 0.6904] [C loss: 1.4618]
# [Epoch 40/50] [Batch 200/938] [D loss: 0.6925] [G loss: 0.6994] [C loss: 1.4906]
# [Epoch 40/50] [Batch 300/938] [D loss: 0.6994] [G loss: 0.6939] [C loss: 1.4657]
# [Epoch 40/50] [Batch 400/938] [D loss: 0.6918] [G loss: 0.6870] [C loss: 1.4701]
# [Epoch 40/50] [Batch 500/938] [D loss: 0.6905] [G loss: 0.6842] [C loss: 1.4741]
# [Epoch 40/50] [Batch 600/938] [D loss: 0.6869] [G loss: 0.6981] [C loss: 1.4903]
# [Epoch 40/50] [Batch 700/938] [D loss: 0.6956] [G loss: 0.6970] [C loss: 1.4768]
# [Epoch 40/50] [Batch 800/938] [D loss: 0.6964] [G loss: 0.7059] [C loss: 1.4612]
# [Epoch 40/50] [Batch 900/938] [D loss: 0.6918] [G loss: 0.7007] [C loss: 1.4772]
# [Epoch 41/50] [Batch 0/938] [D loss: 0.6885] [G loss: 0.7068] [C loss: 1.4619]
# [Epoch 41/50] [Batch 100/938] [D loss: 0.6911] [G loss: 0.6957] [C loss: 1.4769]
# [Epoch 41/50] [Batch 200/938] [D loss: 0.6884] [G loss: 0.7144] [C loss: 1.5013]
# [Epoch 41/50] [Batch 300/938] [D loss: 0.7019] [G loss: 0.6981] [C loss: 1.4926]
# [Epoch 41/50] [Batch 400/938] [D loss: 0.6945] [G loss: 0.6885] [C loss: 1.4882]
# [Epoch 41/50] [Batch 500/938] [D loss: 0.6940] [G loss: 0.6997] [C loss: 1.4766]
# [Epoch 41/50] [Batch 600/938] [D loss: 0.6896] [G loss: 0.6909] [C loss: 1.4699]
# [Epoch 41/50] [Batch 700/938] [D loss: 0.6893] [G loss: 0.6920] [C loss: 1.4863]
# [Epoch 41/50] [Batch 800/938] [D loss: 0.6929] [G loss: 0.7083] [C loss: 1.5058]
# [Epoch 41/50] [Batch 900/938] [D loss: 0.6951] [G loss: 0.7137] [C loss: 1.4624]
# [Epoch 42/50] [Batch 0/938] [D loss: 0.6900] [G loss: 0.7028] [C loss: 1.4612]
# [Epoch 42/50] [Batch 100/938] [D loss: 0.6937] [G loss: 0.6827] [C loss: 1.4750]
# [Epoch 42/50] [Batch 200/938] [D loss: 0.6979] [G loss: 0.6829] [C loss: 1.4793]
# [Epoch 42/50] [Batch 300/938] [D loss: 0.6932] [G loss: 0.6934] [C loss: 1.4843]
# [Epoch 42/50] [Batch 400/938] [D loss: 0.6951] [G loss: 0.6901] [C loss: 1.4613]
# [Epoch 42/50] [Batch 500/938] [D loss: 0.6920] [G loss: 0.6908] [C loss: 1.4768]
# [Epoch 42/50] [Batch 600/938] [D loss: 0.6886] [G loss: 0.6999] [C loss: 1.4766]
# [Epoch 42/50] [Batch 700/938] [D loss: 0.6935] [G loss: 0.6967] [C loss: 1.4761]
# [Epoch 42/50] [Batch 800/938] [D loss: 0.6978] [G loss: 0.6995] [C loss: 1.4759]
# [Epoch 42/50] [Batch 900/938] [D loss: 0.6916] [G loss: 0.6982] [C loss: 1.4651]
# [Epoch 43/50] [Batch 0/938] [D loss: 0.6925] [G loss: 0.6938] [C loss: 1.4791]
# [Epoch 43/50] [Batch 100/938] [D loss: 0.6964] [G loss: 0.6964] [C loss: 1.4612]
# [Epoch 43/50] [Batch 200/938] [D loss: 0.6955] [G loss: 0.7022] [C loss: 1.4756]
# [Epoch 43/50] [Batch 300/938] [D loss: 0.6929] [G loss: 0.6961] [C loss: 1.5030]
# [Epoch 43/50] [Batch 400/938] [D loss: 0.6957] [G loss: 0.6932] [C loss: 1.4621]
# [Epoch 43/50] [Batch 500/938] [D loss: 0.6977] [G loss: 0.7011] [C loss: 1.4772]
# [Epoch 43/50] [Batch 600/938] [D loss: 0.6945] [G loss: 0.7157] [C loss: 1.4626]
# [Epoch 43/50] [Batch 700/938] [D loss: 0.6909] [G loss: 0.7053] [C loss: 1.4957]
# [Epoch 43/50] [Batch 800/938] [D loss: 0.6933] [G loss: 0.7048] [C loss: 1.4613]
# [Epoch 43/50] [Batch 900/938] [D loss: 0.6953] [G loss: 0.6825] [C loss: 1.4612]
# [Epoch 44/50] [Batch 0/938] [D loss: 0.6950] [G loss: 0.6960] [C loss: 1.4768]
# [Epoch 44/50] [Batch 100/938] [D loss: 0.6936] [G loss: 0.7084] [C loss: 1.4925]
# [Epoch 44/50] [Batch 200/938] [D loss: 0.6929] [G loss: 0.6908] [C loss: 1.4755]
# [Epoch 44/50] [Batch 300/938] [D loss: 0.6964] [G loss: 0.7004] [C loss: 1.4924]
# [Epoch 44/50] [Batch 400/938] [D loss: 0.6932] [G loss: 0.6994] [C loss: 1.4917]
# [Epoch 44/50] [Batch 500/938] [D loss: 0.6889] [G loss: 0.6956] [C loss: 1.4880]
# [Epoch 44/50] [Batch 600/938] [D loss: 0.6937] [G loss: 0.6935] [C loss: 1.4778]
# [Epoch 44/50] [Batch 700/938] [D loss: 0.6923] [G loss: 0.6985] [C loss: 1.4771]
# [Epoch 44/50] [Batch 800/938] [D loss: 0.6943] [G loss: 0.7022] [C loss: 1.4786]
# [Epoch 44/50] [Batch 900/938] [D loss: 0.6969] [G loss: 0.7020] [C loss: 1.4924]
# [Epoch 45/50] [Batch 0/938] [D loss: 0.6952] [G loss: 0.7014] [C loss: 1.4615]
# [Epoch 45/50] [Batch 100/938] [D loss: 0.6934] [G loss: 0.6987] [C loss: 1.4769]
# [Epoch 45/50] [Batch 200/938] [D loss: 0.6924] [G loss: 0.6939] [C loss: 1.4765]
# [Epoch 45/50] [Batch 300/938] [D loss: 0.6909] [G loss: 0.6957] [C loss: 1.4612]
# [Epoch 45/50] [Batch 400/938] [D loss: 0.6954] [G loss: 0.6909] [C loss: 1.4869]
# [Epoch 45/50] [Batch 500/938] [D loss: 0.6959] [G loss: 0.6965] [C loss: 1.4859]
# [Epoch 45/50] [Batch 600/938] [D loss: 0.6931] [G loss: 0.6835] [C loss: 1.4787]
# [Epoch 45/50] [Batch 700/938] [D loss: 0.6905] [G loss: 0.6943] [C loss: 1.4924]
# [Epoch 45/50] [Batch 800/938] [D loss: 0.6893] [G loss: 0.6956] [C loss: 1.4760]
# [Epoch 45/50] [Batch 900/938] [D loss: 0.6946] [G loss: 0.7007] [C loss: 1.4787]
# [Epoch 46/50] [Batch 0/938] [D loss: 0.6976] [G loss: 0.6877] [C loss: 1.4933]
# [Epoch 46/50] [Batch 100/938] [D loss: 0.6948] [G loss: 0.7040] [C loss: 1.4766]
# [Epoch 46/50] [Batch 200/938] [D loss: 0.6913] [G loss: 0.6899] [C loss: 1.4624]
# [Epoch 46/50] [Batch 300/938] [D loss: 0.6889] [G loss: 0.6958] [C loss: 1.4925]
# [Epoch 46/50] [Batch 400/938] [D loss: 0.6918] [G loss: 0.6898] [C loss: 1.4754]
# [Epoch 46/50] [Batch 500/938] [D loss: 0.6942] [G loss: 0.6988] [C loss: 1.4768]
# [Epoch 46/50] [Batch 600/938] [D loss: 0.6886] [G loss: 0.6896] [C loss: 1.4619]
# [Epoch 46/50] [Batch 700/938] [D loss: 0.6970] [G loss: 0.7021] [C loss: 1.4685]
# [Epoch 46/50] [Batch 800/938] [D loss: 0.6948] [G loss: 0.6923] [C loss: 1.4853]
# [Epoch 46/50] [Batch 900/938] [D loss: 0.6928] [G loss: 0.7066] [C loss: 1.4841]
# [Epoch 47/50] [Batch 0/938] [D loss: 0.6910] [G loss: 0.6954] [C loss: 1.4612]
# [Epoch 47/50] [Batch 100/938] [D loss: 0.6873] [G loss: 0.7028] [C loss: 1.4830]
# [Epoch 47/50] [Batch 200/938] [D loss: 0.6892] [G loss: 0.6986] [C loss: 1.4768]
# [Epoch 47/50] [Batch 300/938] [D loss: 0.6950] [G loss: 0.6987] [C loss: 1.5024]
# [Epoch 47/50] [Batch 400/938] [D loss: 0.6957] [G loss: 0.6900] [C loss: 1.4612]
# [Epoch 47/50] [Batch 500/938] [D loss: 0.6943] [G loss: 0.6898] [C loss: 1.4731]
# [Epoch 47/50] [Batch 600/938] [D loss: 0.6930] [G loss: 0.6953] [C loss: 1.5070]
# [Epoch 47/50] [Batch 700/938] [D loss: 0.6974] [G loss: 0.6967] [C loss: 1.4772]
# [Epoch 47/50] [Batch 800/938] [D loss: 0.6919] [G loss: 0.7051] [C loss: 1.4994]
# [Epoch 47/50] [Batch 900/938] [D loss: 0.6956] [G loss: 0.6981] [C loss: 1.4779]
# [Epoch 48/50] [Batch 0/938] [D loss: 0.6949] [G loss: 0.6975] [C loss: 1.4892]
# [Epoch 48/50] [Batch 100/938] [D loss: 0.6888] [G loss: 0.6954] [C loss: 1.4613]
# [Epoch 48/50] [Batch 200/938] [D loss: 0.6917] [G loss: 0.6937] [C loss: 1.4612]
# [Epoch 48/50] [Batch 300/938] [D loss: 0.6944] [G loss: 0.6931] [C loss: 1.4612]
# [Epoch 48/50] [Batch 400/938] [D loss: 0.6917] [G loss: 0.6868] [C loss: 1.4802]
# [Epoch 48/50] [Batch 500/938] [D loss: 0.6940] [G loss: 0.6913] [C loss: 1.4794]
# [Epoch 48/50] [Batch 600/938] [D loss: 0.6917] [G loss: 0.7022] [C loss: 1.4614]
# [Epoch 48/50] [Batch 700/938] [D loss: 0.6925] [G loss: 0.7148] [C loss: 1.4703]
# [Epoch 48/50] [Batch 800/938] [D loss: 0.6937] [G loss: 0.7008] [C loss: 1.4894]
# [Epoch 48/50] [Batch 900/938] [D loss: 0.6904] [G loss: 0.6924] [C loss: 1.4784]
# [Epoch 49/50] [Batch 0/938] [D loss: 0.6904] [G loss: 0.6973] [C loss: 1.4750]
# [Epoch 49/50] [Batch 100/938] [D loss: 0.6966] [G loss: 0.6845] [C loss: 1.4768]
# [Epoch 49/50] [Batch 200/938] [D loss: 0.6937] [G loss: 0.6972] [C loss: 1.4688]
# [Epoch 49/50] [Batch 300/938] [D loss: 0.6931] [G loss: 0.6985] [C loss: 1.4774]
# [Epoch 49/50] [Batch 400/938] [D loss: 0.6921] [G loss: 0.6962] [C loss: 1.4921]
# [Epoch 49/50] [Batch 500/938] [D loss: 0.6904] [G loss: 0.6994] [C loss: 1.4768]
# [Epoch 49/50] [Batch 600/938] [D loss: 0.6894] [G loss: 0.7142] [C loss: 1.4627]
# [Epoch 49/50] [Batch 700/938] [D loss: 0.6957] [G loss: 0.6984] [C loss: 1.4940]
# [Epoch 49/50] [Batch 800/938] [D loss: 0.6975] [G loss: 0.6960] [C loss: 1.4701]
# [Epoch 49/50] [Batch 900/938] [D loss: 0.6950] [G loss: 0.7002] [C loss: 1.4773]
# [Epoch 50/50] [Batch 0/938] [D loss: 0.6916] [G loss: 0.6770] [C loss: 1.4652]
# [Epoch 50/50] [Batch 100/938] [D loss: 0.6985] [G loss: 0.6942] [C loss: 1.4941]
# [Epoch 50/50] [Batch 200/938] [D loss: 0.6918] [G loss: 0.6948] [C loss: 1.4838]
# [Epoch 50/50] [Batch 300/938] [D loss: 0.6970] [G loss: 0.6964] [C loss: 1.4768]
# [Epoch 50/50] [Batch 400/938] [D loss: 0.6956] [G loss: 0.6851] [C loss: 1.4615]
# [Epoch 50/50] [Batch 500/938] [D loss: 0.6954] [G loss: 0.7018] [C loss: 1.4764]
# [Epoch 50/50] [Batch 600/938] [D loss: 0.6931] [G loss: 0.7026] [C loss: 1.4768]
# [Epoch 50/50] [Batch 700/938] [D loss: 0.6959] [G loss: 0.7012] [C loss: 1.5196]
# [Epoch 50/50] [Batch 800/938] [D loss: 0.6947] [G loss: 0.7002] [C loss: 1.4651]
# [Epoch 50/50] [Batch 900/938] [D loss: 0.6923] [G loss: 0.6859] [C loss: 1.4776]
